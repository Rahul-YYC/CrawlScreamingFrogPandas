# %%
import pandas as pd

# Display plots directly in the notebook
# %matplotlib inline

# %% [markdown]
# After this, we are ready to import our crawl data directly in two Pandas dataframes:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Colab Notebooks/CrawlScreamingFrogPandas/data/internal_all.csv'

# %% [markdown]
# When your input dataset contains a large number of columns, and you want to load a subset of those columns into a DataFrame, then usecols will be very useful.
# Performance-wise, it is better because instead of loading an entire DataFrame into memory and then deleting the spare columns, we can select the columns we need while loading the dataset.

# %% [markdown]
# The argument header also allows you to specify the row number to use as the column names and the start of data.

# %%
# We skip the first row with `skiprows`, and
# load only useful data with `usecols` argument.
urls = pd.read_csv(path,
                   usecols=["Address","Status Code","Status",
                            "Title 1","Meta Description 1","H1-1","H1-2","Meta Robots 1",
                            "Meta Refresh 1","Canonical Link Element 1","Word Count","Text Ratio",
                            "Crawl Depth","Inlinks","Unique Inlinks","Outlinks","Unique Outlinks",
                            "External Outlinks","Unique External Outlinks","Redirect URL"])

# %%
urls.head(20) # show the first rows of the dataframe: helpful to check if all went right.
# Out:
#                                               Address  ...  Redirect URL
# 0                            https://www.windecor.ca/  ...           NaN
# 1   https://www.windecor.ca/wp-includes/js/wp-embe...  ...           NaN
# 2   https://www.windecor.ca/wp-content/themes/neva...  ...           NaN
# 3   https://www.windecor.ca/banded-sheer-roller-sh...  ...           NaN
# 4   https://www.windecor.ca/wp-content/cache/min/1...  ...           NaN
# 5   https://www.windecor.ca/products/shades/vignet...  ...           NaN
# 6               https://www.windecor.ca/zebra-blinds/  ...           NaN
# 7   https://www.windecor.ca/free-virtual-appointme...  ...           NaN
# 8            https://www.windecor.ca/products/blinds/  ...           NaN
# 9   https://www.windecor.ca/wp-content/plugins/rev...  ...           NaN
# 10                  https://www.windecor.ca/about-us/  ...           NaN
# 11  https://www.windecor.ca/wp-content/cache/min/1...  ...           NaN
# 12  https://www.windecor.ca/hunter-douglas-motoriz...  ...           NaN
# 13                       https://www.windecor.ca/blog  ...           NaN
# 14  https://www.windecor.ca/wp-content/cache/min/1...  ...           NaN
# 15                  https://www.windecor.ca/products/  ...           NaN
# 16  https://www.windecor.ca/wp-content/cache/min/1...  ...           NaN
# 17  https://www.windecor.ca/products/shades/piroue...  ...           NaN
# 18  https://www.windecor.ca/wp-content/cache/min/1...  ...           NaN
# 19  https://www.windecor.ca/products/shades/silhou...  ...           NaN
#
# [20 rows x 20 columns]

# %% [markdown]
# Analyze a little with the data. Let's count URLs per Status Code:
